# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)

# %%
db = client['sakila']
customers = db['customers']

# %%
customers.find_one()
# Out:
# {'_id': 3,
#  'Address': '692 Joliet Street',
#  'City': 'Athenai',
#  'Country': 'Greece',
#  'District': 'Attika',
#  'First Name': 'LINDA',
#  'Last Name': 'WILLIAMS',
#  'Phone': '448477190408',
#  'Rentals': [{'Film Title': 'RINGS HEARTBREAKERS',
#    'Payments': [{'Amount': 1.9900000095367432,
#      'Payment Date': '2005-05-27 17:17:09.0',
#      'Payment Id': 60}],
#    'Rental Date': '2005-05-27 17:17:09.0',
#    'Return Date': '2005-06-02 11:20:09.0',
#    'filmId': 732,
#    'rentalId': 435,
#    'staffId': 2},
#   {'Film Title': 'ANACONDA CONFESSIONS',
#    'Payments': [{'Amount': 6.989999771118164,
#      'Payment Date': '2005-06-16 15:19:10.0',
#      'Payment Id': 63}],
#    'Rental Date': '2005-06-16 15:19:10.0',
#    'Return Date': '2005-06-25 11:39:10.0',
#    'filmId': 23,
#    'rentalId': 1726,
#    'staffId': 2},
#   {'Film Title': 'DADDY PITTSBURGH',
#    'Payments': [{'Amount': 6.989999771118164,
#      'Payment Date': '2005-06-17 05:15:15.0',
# ...
